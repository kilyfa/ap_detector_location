# %%
# Data Imports
import pandas as pd
import warnings

# Preprocessing 
from sklearn.preprocessing import StandardScaler, LabelEncoder, MinMaxScaler, RobustScaler
from collections import Counter
from imblearn.over_sampling import SMOTE

# Classification 
from sklearn.svm import SVC # For SVM Model
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score # For visualizing CReport, CM, and accuracy
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split # For Validation Model

# Visualization Imports
import seaborn as sns
import matplotlib.pyplot as plt 
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import plotly.express as px
import plotly.io as pio

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("dataset_model_per_lantai.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 94 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   06:70:ab:a7:aa:b3:  46 non-null     float64
#  1   06:0d:9e:25:7e:2e:  46 non-null     float64
#  2   ea:d0:f5:9b:f4:2f:  46 non-null     float64
#  3   06:70:ab:a7:ab:83:  46 non-null     float64
#  4   06:0d:9e:25:7b:32:  46 non-null     float64
#  5   06:70:ab:a7:aa:ff:  46 non-null     float64
#  6   06:0d:9e:a8:88:79:  46 non-null     float64
#  7   06:70:ab:a7:aa:fe:  46 non-null     float64
#  8   06:70:ab:a7:ab:82:  46 non-null     float64
#  9   06:70:ab:a7:ab:87:  46 non-null     float64
#  10  06:0d:9e:a8:8e:6d:  46 non-null     float64
#  11  06:0d:9e:a8:8a:5c:  46 non-null     float64
#  12  06:0d:9e:25:7b:1a:  46 non-null     float64
#  13  06:0d:9e:a8:8e:a5:  46 non-null     float64
#  14  06:70:ab:a7:ab:86:  46 non-null     float64
#  15  06:70:ab:a7:ab:7a:  46 non-null     float64
#  16  06:0d:9e:a8:8b:7c:  46 non-null     float64
#  17  06:0d:9e:25:7b:19:  46 non-null     float64
#  18  06:0d:9e:25:7b:0a:  46 non-null     float64
#  19  06:0d:9e:a8:85:2c:  46 non-null     float64
#  20  06:0d:9e:a8:8e:6c:  46 non-null     float64
#  21  06:0d:9e:25:7b:09:  46 non-null     float64
#  22  06:70:ab:a7:ab:8a:  46 non-null     float64
#  23  06:0d:9e:a8:8a:f9:  46 non-null     float64
#  24  ea:d0:f5:9b:e8:bf:  46 non-null     float64
#  25  06:0d:9e:a8:88:78:  46 non-null     float64
#  26  fa:d0:f5:9b:e8:b0:  46 non-null     float64
#  27  06:0d:9e:a8:8a:f8:  46 non-null     float64
#  28  06:0d:9e:a8:8e:69:  46 non-null     float64
#  29  06:0d:9e:a8:8e:a4:  46 non-null     float64
#  30  06:0d:9e:a8:8a:98:  46 non-null     float64
#  31  06:0d:9e:a8:88:d4:  46 non-null     float64
#  32  06:0d:9e:a8:85:2d:  46 non-null     float64
#  33  Unnamed: 33         46 non-null     int64
#  34  06:0d:9e:25:7a:de:  46 non-null     float64
#  35  06:0d:9e:25:7b:31:  46 non-null     float64
#  36  fa:d0:f5:9b:f4:20:  46 non-null     float64
#  37  06:70:ab:a7:aa:b2:  46 non-null     float64
#  38  06:0d:9e:25:7a:dd:  46 non-null     float64
#  39  06:0d:9e:25:7e:99:  46 non-null     float64
#  40  06:0d:9e:25:7a:b1:  46 non-null     float64
#  41  06:70:ab:a7:ab:8b:  46 non-null     float64
#  42  06:70:ab:a7:ab:7b:  46 non-null     float64
#  43  06:0d:9e:25:7f:12:  46 non-null     float64
#  44  2a:d0:f5:9b:e3:13:  46 non-null     float64
#  45  06:0d:9e:25:7f:11:  46 non-null     float64
#  46  06:0d:9e:44:8a:23:  46 non-null     float64
#  47  06:0d:9e:44:88:b7:  46 non-null     float64
#  48  9a:4a:6b:83:72:0e:  46 non-null     float64
#  49  0a:70:ab:a7:3d:23:  46 non-null     float64
#  50  0a:70:ab:a7:ab:97:  46 non-null     float64
#  51  06:0d:9e:44:5e:82:  46 non-null     float64
#  52  9c:2b:a6:8f:7b:14:  46 non-null     float64
#  53  06:0d:9e:25:7e:aa:  46 non-null     float64
#  54  06:0d:9e:25:7a:b2:  46 non-null     float64
#  55  06:0d:9e:a8:88:d5:  46 non-null     float64
#  56  06:0d:9e:25:7e:2d:  46 non-null     float64
#  57  3a:d0:f5:9b:e3:14:  46 non-null     float64
#  58  06:0d:9e:a8:8a:99:  46 non-null     float64
#  59  06:0d:9e:a8:8b:7d:  46 non-null     float64
#  60  06:0d:9e:25:7e:9a:  46 non-null     float64
#  61  06:70:ab:a7:ab:93:  46 non-null     float64
#  62  06:70:ab:a7:ac:0b:  46 non-null     float64
#  63  06:0d:9e:25:76:6e:  46 non-null     float64
#  64  9c:2b:a6:8f:7b:ff:  46 non-null     float64
#  65  06:0d:9e:a8:72:c0:  46 non-null     float64
#  66  06:0d:9e:25:76:6d:  46 non-null     float64
#  67  06:0d:9e:a8:8a:5d:  46 non-null     float64
#  68  9c:2b:a6:8f:7c:00:  46 non-null     float64
#  69  06:0d:9e:a8:72:c1:  46 non-null     float64
#  70  06:0d:9e:a8:8a:e8:  46 non-null     float64
#  71  06:70:ab:a7:ab:92:  46 non-null     float64
#  72  06:0d:9e:25:7a:ea:  46 non-null     float64
#  73  06:0d:9e:a8:87:e1:  46 non-null     float64
#  74  06:0d:9e:a8:8a:6d:  46 non-null     float64
#  75  06:0d:9e:1f:1e:f1:  46 non-null     float64
#  76  3a:d0:f5:9b:e7:f4:  46 non-null     float64
#  77  06:0d:9e:a8:87:e0:  46 non-null     float64
#  78  06:0d:9e:25:86:21:  46 non-null     float64
#  79  06:0d:9e:a8:8b:50:  46 non-null     float64
#  80  e2:5d:54:81:22:a6:  46 non-null     float64
#  81  06:0d:9e:a8:84:0d:  46 non-null     float64
#  82  06:0d:9e:a8:8b:51:  46 non-null     float64
#  83  06:0d:9e:a8:8a:9c:  46 non-null     float64
#  84  06:0d:9e:a8:77:98:  46 non-null     float64
#  85  2a:d0:f5:9b:e7:f3:  46 non-null     float64
#  86  0a:70:ab:a7:3d:22:  46 non-null     float64
#  87  9c:2b:a6:8f:7a:c4:  46 non-null     float64
#  88  06:0d:9e:a8:8a:9d:  46 non-null     float64
#  89  06:0d:9e:25:86:22:  46 non-null     float64
#  90  06:0d:9e:a8:89:dd:  46 non-null     float64
#  91  06:0d:9e:a8:8a:e9:  46 non-null     float64
#  92  06:0d:9e:a8:8a:dd:  46 non-null     float64
#  93  spot                46 non-null     object
# dtypes: float64(92), int64(1), object(1)
# memory usage: 33.9+ KB

# %%
df_train = df.drop(columns=["Unnamed: 33"])
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 93 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   06:70:ab:a7:aa:b3:  46 non-null     float64
#  1   06:0d:9e:25:7e:2e:  46 non-null     float64
#  2   ea:d0:f5:9b:f4:2f:  46 non-null     float64
#  3   06:70:ab:a7:ab:83:  46 non-null     float64
#  4   06:0d:9e:25:7b:32:  46 non-null     float64
#  5   06:70:ab:a7:aa:ff:  46 non-null     float64
#  6   06:0d:9e:a8:88:79:  46 non-null     float64
#  7   06:70:ab:a7:aa:fe:  46 non-null     float64
#  8   06:70:ab:a7:ab:82:  46 non-null     float64
#  9   06:70:ab:a7:ab:87:  46 non-null     float64
#  10  06:0d:9e:a8:8e:6d:  46 non-null     float64
#  11  06:0d:9e:a8:8a:5c:  46 non-null     float64
#  12  06:0d:9e:25:7b:1a:  46 non-null     float64
#  13  06:0d:9e:a8:8e:a5:  46 non-null     float64
#  14  06:70:ab:a7:ab:86:  46 non-null     float64
#  15  06:70:ab:a7:ab:7a:  46 non-null     float64
#  16  06:0d:9e:a8:8b:7c:  46 non-null     float64
#  17  06:0d:9e:25:7b:19:  46 non-null     float64
#  18  06:0d:9e:25:7b:0a:  46 non-null     float64
#  19  06:0d:9e:a8:85:2c:  46 non-null     float64
#  20  06:0d:9e:a8:8e:6c:  46 non-null     float64
#  21  06:0d:9e:25:7b:09:  46 non-null     float64
#  22  06:70:ab:a7:ab:8a:  46 non-null     float64
#  23  06:0d:9e:a8:8a:f9:  46 non-null     float64
#  24  ea:d0:f5:9b:e8:bf:  46 non-null     float64
#  25  06:0d:9e:a8:88:78:  46 non-null     float64
#  26  fa:d0:f5:9b:e8:b0:  46 non-null     float64
#  27  06:0d:9e:a8:8a:f8:  46 non-null     float64
#  28  06:0d:9e:a8:8e:69:  46 non-null     float64
#  29  06:0d:9e:a8:8e:a4:  46 non-null     float64
#  30  06:0d:9e:a8:8a:98:  46 non-null     float64
#  31  06:0d:9e:a8:88:d4:  46 non-null     float64
#  32  06:0d:9e:a8:85:2d:  46 non-null     float64
#  33  06:0d:9e:25:7a:de:  46 non-null     float64
#  34  06:0d:9e:25:7b:31:  46 non-null     float64
#  35  fa:d0:f5:9b:f4:20:  46 non-null     float64
#  36  06:70:ab:a7:aa:b2:  46 non-null     float64
#  37  06:0d:9e:25:7a:dd:  46 non-null     float64
#  38  06:0d:9e:25:7e:99:  46 non-null     float64
#  39  06:0d:9e:25:7a:b1:  46 non-null     float64
#  40  06:70:ab:a7:ab:8b:  46 non-null     float64
#  41  06:70:ab:a7:ab:7b:  46 non-null     float64
#  42  06:0d:9e:25:7f:12:  46 non-null     float64
#  43  2a:d0:f5:9b:e3:13:  46 non-null     float64
#  44  06:0d:9e:25:7f:11:  46 non-null     float64
#  45  06:0d:9e:44:8a:23:  46 non-null     float64
#  46  06:0d:9e:44:88:b7:  46 non-null     float64
#  47  9a:4a:6b:83:72:0e:  46 non-null     float64
#  48  0a:70:ab:a7:3d:23:  46 non-null     float64
#  49  0a:70:ab:a7:ab:97:  46 non-null     float64
#  50  06:0d:9e:44:5e:82:  46 non-null     float64
#  51  9c:2b:a6:8f:7b:14:  46 non-null     float64
#  52  06:0d:9e:25:7e:aa:  46 non-null     float64
#  53  06:0d:9e:25:7a:b2:  46 non-null     float64
#  54  06:0d:9e:a8:88:d5:  46 non-null     float64
#  55  06:0d:9e:25:7e:2d:  46 non-null     float64
#  56  3a:d0:f5:9b:e3:14:  46 non-null     float64
#  57  06:0d:9e:a8:8a:99:  46 non-null     float64
#  58  06:0d:9e:a8:8b:7d:  46 non-null     float64
#  59  06:0d:9e:25:7e:9a:  46 non-null     float64
#  60  06:70:ab:a7:ab:93:  46 non-null     float64
#  61  06:70:ab:a7:ac:0b:  46 non-null     float64
#  62  06:0d:9e:25:76:6e:  46 non-null     float64
#  63  9c:2b:a6:8f:7b:ff:  46 non-null     float64
#  64  06:0d:9e:a8:72:c0:  46 non-null     float64
#  65  06:0d:9e:25:76:6d:  46 non-null     float64
#  66  06:0d:9e:a8:8a:5d:  46 non-null     float64
#  67  9c:2b:a6:8f:7c:00:  46 non-null     float64
#  68  06:0d:9e:a8:72:c1:  46 non-null     float64
#  69  06:0d:9e:a8:8a:e8:  46 non-null     float64
#  70  06:70:ab:a7:ab:92:  46 non-null     float64
#  71  06:0d:9e:25:7a:ea:  46 non-null     float64
#  72  06:0d:9e:a8:87:e1:  46 non-null     float64
#  73  06:0d:9e:a8:8a:6d:  46 non-null     float64
#  74  06:0d:9e:1f:1e:f1:  46 non-null     float64
#  75  3a:d0:f5:9b:e7:f4:  46 non-null     float64
#  76  06:0d:9e:a8:87:e0:  46 non-null     float64
#  77  06:0d:9e:25:86:21:  46 non-null     float64
#  78  06:0d:9e:a8:8b:50:  46 non-null     float64
#  79  e2:5d:54:81:22:a6:  46 non-null     float64
#  80  06:0d:9e:a8:84:0d:  46 non-null     float64
#  81  06:0d:9e:a8:8b:51:  46 non-null     float64
#  82  06:0d:9e:a8:8a:9c:  46 non-null     float64
#  83  06:0d:9e:a8:77:98:  46 non-null     float64
#  84  2a:d0:f5:9b:e7:f3:  46 non-null     float64
#  85  0a:70:ab:a7:3d:22:  46 non-null     float64
#  86  9c:2b:a6:8f:7a:c4:  46 non-null     float64
#  87  06:0d:9e:a8:8a:9d:  46 non-null     float64
#  88  06:0d:9e:25:86:22:  46 non-null     float64
#  89  06:0d:9e:a8:89:dd:  46 non-null     float64
#  90  06:0d:9e:a8:8a:e9:  46 non-null     float64
#  91  06:0d:9e:a8:8a:dd:  46 non-null     float64
#  92  spot                46 non-null     object
# dtypes: float64(92), object(1)
# memory usage: 33.6+ KB

# %%
x = df_train.drop(columns=["spot"])
y = df_train["spot"]

# %%
# Normalisasi data fitur(x)
STscaler = StandardScaler()
x_scaled = STscaler.fit_transform(x)
x_scaled = STscaler.transform(x)
print(x_scaled)
# Out:
# [[-0.42884127 -0.0831996  -0.47763248 ... -0.1490712  -0.1490712
#   -0.1490712 ]
#  [ 0.27568368 -0.75858462  0.09304529 ... -0.1490712  -0.1490712
#   -0.1490712 ]
#  [-0.10860266 -0.75858462 -0.1922936  ... -0.1490712  -0.1490712
#   -0.1490712 ]
#  ...
#  [-0.42884127 -0.15824238 -0.40629776 ... -0.1490712  -0.1490712
#   -0.1490712 ]
#  [ 1.04425635  0.89235654  0.02171057 ... -0.1490712  -0.1490712
#   -0.1490712 ]
#  [-0.94122305 -0.75858462 -1.11964497 ... -0.1490712  -0.1490712
#   -0.1490712 ]]

# %%
# Untuk Validasi model menggunakan train_test_split dengan rasio data split 80:20
X_train, X_test, y_train, y_test = train_test_split(x_scaled, 
                                                    y, test_size = 0.3,
                                                    random_state = 42)
print('Classes and number of values in trainset',Counter(y_train))
# Out:
# Classes and number of values in trainset Counter({'Lantai 4': 9, 'Lantai 1': 8, 'Lantai 2': 8, 'Lantai 3': 7})

# %%
# Pemodelan
svm = SVC()

# %%
# Fit Model / Train model
svm.fit(X_train,y_train)
# Out:
# SVC()

# %%
# Lakukan Predict test data ke model yang telah dilatih
y_pred_svm = svm.predict(X_test)

# %%
# Buat dictionary model dan hasil prediksi
models = {
    "SVM": (svm, y_pred_svm),
}

# Loop evaluasi
for name, (model, y_pred) in models.items():
    print(f"\n{name}")
    print("Classification Report:")
    print(classification_report(y_test, y_pred))
    print("Confusion Matrix:")
    print(confusion_matrix(y_test, y_pred))
    acc = accuracy_score(y_test, y_pred) * 100
    print(f"Accuracy: {acc:.1f}%")
# Out:
# SVM
# Classification Report:
#               precision    recall  f1-score   support
#
#     Lantai 1       1.00      1.00      1.00         5
#     Lantai 2       1.00      1.00      1.00         3
#     Lantai 3       1.00      1.00      1.00         1
#     Lantai 4       1.00      1.00      1.00         5
#
#     accuracy                           1.00        14
#    macro avg       1.00      1.00      1.00        14
# weighted avg       1.00      1.00      1.00        14
#
# Confusion Matrix:
# [[5 0 0 0]
#  [0 3 0 0]
#  [0 0 1 0]
#  [0 0 0 5]]
# Accuracy: 100.0%

# %%
# Tampilkan Semua Akurasi
accuracy = {
    'Model': ['SVM'],
    'Accuracy': [
        accuracy_score(y_test, y_pred_svm),
    ]
}

accuracy_df = pd.DataFrame(accuracy)

# Format the 'Accuracy' column as percentages with one decimal place
accuracy_df['Accuracy'] = accuracy_df['Accuracy'].apply(lambda x: f"{x:.1%}")

# Sort the DataFrame by the 'Precision' column in descending order
accuracy_df = accuracy_df.sort_values(by='Accuracy', ascending=False)

print("\nSummary of Model Accuracy")
print(accuracy_df)
# Out:
# Summary of Model Accuracy
#   Model Accuracy
# 0   SVM   100.0%

# %%
# Weighted Precision
precision = {
    'Model': ['SVM'],
    'Precision': [
        precision_score(y_test, y_pred_svm, average='weighted')
    ]
}
precision_df = pd.DataFrame(precision)

# Format the 'Precision' column as percentages with one decimal place
precision_df['Precision'] = precision_df['Precision'].apply(lambda x: f"{x:.1%}")

# Sort the DataFrame by the 'Precision' column in descending order
precision_df = precision_df.sort_values(by='Precision', ascending=False)

print("\nSummary of Model Precision")
print(precision_df)
# Out:
# Summary of Model Precision
#   Model Precision
# 0   SVM    100.0%

# %%
# Weighted recall
recall = {
    'Model': ['SVM'],
    'Recall': [
        recall_score(y_test, y_pred_svm, average='weighted')
    ]
}
recall_df = pd.DataFrame(recall)

# Format the 'Precision' column as percentages with one decimal place
recall_df['Recall'] = recall_df['Recall'].apply(lambda x: f"{x:.1%}")

# Sort the DataFrame by the 'Precision' column in descending order
recall_df = recall_df.sort_values(by='Recall', ascending=False)

print("\nSummary of Model Recall")
print(recall_df)
# Out:
# Summary of Model Recall
#   Model  Recall
# 0   SVM  100.0%

# %%
# Weighted f1-score
f1 = {
    'Model': ['SVM'],
    'f1': [
        f1_score(y_test, y_pred_svm, average='weighted')
    ]
}
f1_df = pd.DataFrame(f1)

# Format the 'Precision' column as percentages with one decimal place
f1_df['f1'] = f1_df['f1'].apply(lambda x: f"{x:.1%}")

# Sort the DataFrame by the 'Precision' column in descending order
f1_df = f1_df.sort_values(by='f1', ascending=False)

print("\nSummary of Model F1-Score")
print(f1_df)
# Out:
# Summary of Model F1-Score
#   Model      f1
# 0   SVM  100.0%

# %%
precision = {
    'Model': ['SVM'],
    'Precision': [
        precision_score(y_test, y_pred_svm, average='weighted')
    ]
}
precision_df = pd.DataFrame(precision)

precision_df['Precision'] = precision_df['Precision'].apply(lambda x: f"{x:.1%}")

print(precision_df)
# Out:
#   Model Precision
# 0   SVM    100.0%

# %%
merged_df = precision_df.merge(recall_df, on='Model').merge(f1_df, on='Model').merge(accuracy_df, on='Model')

merged_df['Precision'] = merged_df['Precision']
merged_df['Recall'] = merged_df['Recall']
merged_df['f1'] = merged_df['f1']
merged_df['Accuracy'] = merged_df['Accuracy']

merged_df = merged_df.sort_values(by='Accuracy', ascending=False)

merged_df
# Out:
#   Model Precision  Recall      f1 Accuracy
# 0   SVM    100.0%  100.0%  100.0%   100.0%

# %%
import joblib

joblib.dump(svm, 'svm_model.pkl')
# Out:
# ['svm_model.pkl']
